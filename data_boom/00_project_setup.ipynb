# %% [markdown]
# # Notebook 1: 00_project_setup
# Project setup: imports, seed, output folders, and shared definitions.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sqlite3
from pathlib import Path

# %%
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

PROJECT_ROOT = Path.cwd()
DATA_DIR = PROJECT_ROOT / 'data'
FIG_DIR = PROJECT_ROOT / 'figures'
DATA_DIR.mkdir(parents=True, exist_ok=True)
FIG_DIR.mkdir(parents=True, exist_ok=True)
print('Project root:', PROJECT_ROOT)
print('Data dir:', DATA_DIR)
print('Figure dir:', FIG_DIR)

# %%
SCENE_TYPES = ['residential_area', 'arterial_road', 'construction_site', 'industrial_park']
NEGATIVE_CLASSES = ['truck_horn', 'piling', 'vehicle_backfire', 'metal_hit', 'crowd_noise', 'machinery', 'wind_rain']
DEVICE_PARAMS = {
    'n_devices': 120,
    'regions': [f'R{i:02d}' for i in range(1, 9)],
    'install_types': ['pole', 'building_wall', 'roof'],
    'firmware_versions': ['fw_1.7.2', 'fw_1.8.0', 'fw_1.8.3'],
    'threshold_versions': ['v060', 'v070', 'v080', 'v085', 'v090'],
    'mic_array_types': ['4mic_linear', '6mic_circular'],
    'status_values': ['active', 'maintenance'],
}
TARGET_CONFUSION = {'TP': 2418, 'FN': 376, 'FP': 534, 'TN': 5874}
FP_CLASS_TARGET = {
    'truck_horn': 205, 'piling': 158, 'vehicle_backfire': 72,
    'metal_hit': 46, 'crowd_noise': 31, 'machinery': 15, 'wind_rain': 7,
}
print('Target confusion:', TARGET_CONFUSION)
